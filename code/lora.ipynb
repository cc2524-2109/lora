# %%
# !pwd
# Out:
# /home/karaikals/lora/code

# %%
# !pip install --upgrade torch --pre --index-url https://download.pytorch.org/whl/nightly/cu128

# %%
# !pip install transformers datasets accelerate

# %%
import torch
import transformers
import datasets
import accelerate

print(f"PyTorch version: {torch.__version__}")
print(f"Transformers version: {transformers.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU Device: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.12.0.dev20260408+cu128
# Transformers version: 5.5.4
# CUDA available: True
# GPU Device: NVIDIA GeForce RTX 5070

# %%
#importing necessary libs and methods
import torch 
from transformers import GPT2LMHeadModel #that means, do we need to install this transformers model
from lora import inject_lora

# %%
#let's load and inject 
model = GPT2LMHeadModel.from_pretrained("gpt2")
model = inject_lora(model, rank=4, alpha=32)
model.eval()
print(f"LoRA injected successfully")
# Out:
# ...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# LoRA injected successfully

# %%
#since, we freezed all the earlier ones we need to check only LoRA params are trainable
from transformers import GPT2LMHeadModel
from lora import inject_lora

# loading the model
model = GPT2LMHeadModel.from_pretrained("gpt2")
    
# inject using table 11 settings
model = inject_lora(model, rank=4, alpha=32)
    
print("installation plus LoRA injection successful!")
    
# counbt how many trainable params
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"trainable params: {trainable:,}")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# installation plus LoRA injection successful!
# trainable params: 147,456
